# %% [markdown]
# # Data
#
# The data will come from foursquare.
# I used the api to search in the different postal codes (19 are present in this city) for 50 restaurants and put the information in one single dataframe.
# Later the ratings will be extracted and also put into the dataframe.
#
# Here is a screenshot of the raw data already collected:
#
# ![Data.JPG](attachment:Data.JPG)
